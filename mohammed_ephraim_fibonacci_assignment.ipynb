# %%
import math
c=input('input your fibonacci range here: ')
a = 1
b=0
for i in range(int(c)):
  b=a+b
  a, b = b , a
  print(b)
  i +=1
# Out:
# input your fibonacci range here: 7
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %%
7a=6
b=7
a+b
# Out:
# 13
